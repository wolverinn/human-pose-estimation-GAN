# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip3 install chumpy
# !pip3 install deepdish>=0.3
# !pip3 install opendr
# Out:
# ...
#      |████████████████████████████████| 51kB 1.1MB/s
# ...
#   Created wheel for chumpy: filename=chumpy-0.69-cp36-none-any.whl size=58290 sha256=ee56d795a6f48e3622c17c8a40479887ab43eb843ad357978c7485ea8f11f892
#   Stored in directory: /root/.cache/pip/wheels/df/11/36/2758327d759bad62803f3f9190db1c063e52a0358cecd33e94
# Successfully built chumpy
# ...

# %%
# !wget https://github.com/mattloper/opendr/archive/master.zip
# !unzip master.zip
# !rm master.zip
import shutil
shutil.copy("/content/drive/My Drive/demo/OSMesa.Linux.x86_64.zip", "/content/opendr-master/opendr/contexts/OSMesa.Linux.x86_64.zip")
# %cd opendr-master
# !python3 setup.py build
# !python3 setup.py install
# %cd ..
# Out:
# --2020-05-29 00:50:33--  https://github.com/mattloper/opendr/archive/master.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/mattloper/opendr/zip/master [following]
# --2020-05-29 00:50:33--  https://codeload.github.com/mattloper/opendr/zip/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [ <=>                ]  64.78K  --.-KB/s    in 0.04s
#
# 2020-05-29 00:50:34 (1.45 MB/s) - ‘master.zip’ saved [66331]
#
# Archive:  master.zip
# bc16a6a51771d6e062d088ba5cede66649b7c7ec
#    creating: opendr-master/
#   inflating: opendr-master/.gitignore
# ...

# %% [markdown]
# ## Demo
#
# To test time efficiency: run twice.

# %%
# source code from github
# !wget https://github.com/wolverinn/human-pose-estimation-GAN/archive/master.zip
# !unzip master.zip
# !rm master.zip
# !rm -rf ./src/
# !mv ./human-pose-estimation-GAN-master/src ./src
# !mv ./human-pose-estimation-GAN-master/demo.py ./demo.py
# !rm -rf human-pose-estimation-GAN-master
# demo image from drive
import shutil
shutil.copytree("/content/drive/My Drive/demo/data", "/content/data")
# Out:
# --2020-05-29 00:51:05--  https://github.com/wolverinn/human-pose-estimation-GAN/archive/master.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/wolverinn/human-pose-estimation-GAN/zip/master [following]
# --2020-05-29 00:51:06--  https://codeload.github.com/wolverinn/human-pose-estimation-GAN/zip/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [ <=>                ] 247.78K  --.-KB/s    in 0.07s
#
# 2020-05-29 00:51:06 (3.41 MB/s) - ‘master.zip’ saved [253729]
#
# Archive:  master.zip
# 25f48f245341b386cd6fc5422ef814ec7faed90b
# ...

# %%
# !python3 -m demo --img_path data/coco6.png
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/demo.py:123: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-05-29 00:54:26.101195: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-29 00:54:26.117593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python3 -m demo --img_path data/im1963.jpg
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/demo.py:123: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-05-29 00:55:26.924545: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-29 00:55:26.941182: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
